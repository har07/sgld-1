sgld = [22.003,36.605,44.319,53.164,62.153,66.188,71.438,73.508,76.337,76.728,77.583,77.786,77.206,78.300,80.917,79.031,79.287,80.769,80.079,81.511,82.922,82.541,81.787,82.741,82.873,83.032,82.742,82.313,82.608,83.244,83.997,83.839,83.004,83.211,83.973,81.957,83.191,82.708,83.900,82.944,82.500,84.132,84.192,83.546,83.776,84.218,83.433,83.569,84.211,83.654,83.532,84.538,84.081,84.849,84.800,84.798,84.967,84.553,85.362,84.288,83.912,83.378,84.356,84.625,83.998,83.608,84.047,84.421,84.370,85.268,84.951,85.564,85.438,84.854,85.389,85.239,85.585,84.734,85.306,85.745,85.775,85.117,85.509,85.329,85.469,84.776,85.794,85.594,86.340,86.176,85.733,85.940,85.984,85.906,86.272,86.562,86.488,86.262,86.893,86.977,87.310,87.161,86.910,87.469,86.965,87.115,86.475,86.399,87.151,87.277,87.743,87.952,87.918,87.935,87.342,87.434,87.705,87.388,87.899,87.919,87.272,87.388,87.339,87.087,87.078,87.252,87.703,87.587,87.562,87.144,87.671,87.437,87.311,86.273,86.253,86.420,86.232,86.376,87.141,87.454,87.055,87.743,87.948,88.002,87.247,86.881,86.520,86.471]

plt.rc('font', size=15)
plt.plot(psgld_no_noise, label='pSGLD no noise')
plt.plot(sgd, label='SGD')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('validation accuracy')
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(100))
plt.savefig('output1.png', dpi=300)

# %%
plt.rc('font', size=15)
plt.plot(sgld, label='SGLD')
# plt.plot(sgld2[:10], label='SGLD lr=0.0021')
plt.plot(psgld, label='pSGLD')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('validation accuracy')
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(100))
plt.savefig('output2.png', dpi=300)

# fig, ax = plt.subplots()
# idx_sgld = [19,39,59]
# plt.scatter(idx_sgld, [x for i,x in enumerate(sgld) if i in idx_sgld])
# idx_psgld = [19]
# plt.scatter(idx_psgld, [x for i,x in enumerate(psgld) if i in idx_psgld])

# %%
fig, axs = plt.subplots(2)
plt.subplots_adjust(hspace=1)
# fig.suptitle('Vertically stacked subplots')
plt.rc('font', size=15)
plt.setp(axs[:], xlabel='epoch')
plt.setp(axs[:], ylabel='validation accuracy')
axs[0].plot(psgld_no_noise, label='pSGLD no noise')
axs[0].plot(sgd, label='SGD')
axs[0].legend()
axs[0].yaxis.set_major_formatter(mtick.PercentFormatter(100))

axs[1].plot(psgld, label='pSGLD')
axs[1].plot(sgld[, label='SGLD')
axs[1].legend()
axs[1].yaxis.set_major_formatter(mtick.PercentFormatter(100))

# axs[1].plot(x, -y)
